# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\shiva\Downloads\Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# # Line chart

# %%
df['Age'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Scatter plot

# %%
df.plot(kind = 'scatter', x = 'Age', y = 'Annual Income (k$)')
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income (k$)'>

# %%
# to find the corelation 
print(df['Age'].corr(df['Annual Income (k$)']))
# Out:
# -0.01239804273606013

# %% [markdown]
# # Histogram

# %%
df['Age'].plot(kind = 'hist',bins = 30,edgecolor = 'y',log = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['Age','Annual Income (k$)','Spending Score (1-100)']].plot(kind = 'hist',bins = 30,alpha = 0.5,fontsize = 5,edgecolor = 'r')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # bar and BARh chart

# %%
df[['Age','Annual Income (k$)','Spending Score (1-100)']].plot(kind = 'bar',alpha = 0.5,fontsize = 5)
# Out:
# <Axes: >

# %%
Bar_chart = round(df.groupby("Gender")[["Annual Income (k$)","Age"]].mean(),2)
print(Bar_chart)
Bar_chart.plot(kind = 'bar',alpha = 1,fontsize = 10)
# Out:
#         Annual Income (k$)    Age
# Gender
# Female               59.25  38.10
# Male                 62.23  39.81
# <Axes: xlabel='Gender'>

# %%
Bar_chart = df.groupby(["Gender"])[["Annual Income (k$)","Spending Score (1-100)"]].mean()
#print(Bar_chart)
Bar_chart.plot(kind = 'bar',alpha = 0.5,fontsize = 9,edgecolor = "r")
# Out:
# <Axes: xlabel='Gender'>

# %%
df1 = df.groupby(["Gender"])[["Annual Income (k$)","Spending Score (1-100)"]].mean()
df1
# Out:
#         Annual Income (k$)  Spending Score (1-100)
# Gender
# Female           59.250000               51.526786
# Male             62.227273               48.511364

# %% [markdown]
# # Pie chart

# %%
df1.plot(kind ='pie',subplots = True)
# Out:
# array([<Axes: ylabel='Annual Income (k$)'>,
#        <Axes: ylabel='Spending Score (1-100)'>], dtype=object)

# %%
df1.plot.bar(color = ['green','yellow'],subplots = True,alpha = 0.7)
# Out:
# array([<Axes: title={'center': 'Annual Income (k$)'}, xlabel='Gender'>,
#        <Axes: title={'center': 'Spending Score (1-100)'}, xlabel='Gender'>],
#       dtype=object)

# %% [markdown]
# # Box plot

# %%
df.plot(kind = "box")
# Out:
# <Axes: >

# %%
import numpy as np
q1 = np.quantile(df['Annual Income (k$)'],0.25)
print('q1',q1)

q2 = np.quantile(df['Annual Income (k$)'],0.5)
print('q2',q2)

q3 = np.quantile(df['Annual Income (k$)'],0.75)
print('q3',q3)

iqr = (q3 - q1)
print('iqr',iqr)
min,max = q3-1.5*iqr,q1+1.5*iqr
iqrrange = [min,max]
iqrrange
# Out:
# q1 41.5
# q2 61.5
# q3 78.0
# iqr 36.5
# [23.25, 96.25]

# %%
range = df[(df['Annual Income (k$)'] >= min) & (df['Annual Income (k$)'] <= max)]
range.count()
# Out:
# CustomerID                160
# Gender                    160
# Age                       160
# Annual Income (k$)        160
# Spending Score (1-100)    160
# dtype: int64

# %% [markdown]
# # Area plot

# %%
df.plot(kind = 'area',alpha = 0.5)
# Out:
# <Axes: >

# %% [markdown]
# # KDE plot

# %%
df.plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind = 'hexbin',x="Age",y = (["Annual Income (k$)"]),gridsize = 15)
# Out:
# <Axes: xlabel='Age', ylabel='[Annual Income (k$)]'>

# %%
df.plot(kind = 'hexbin',x="Age",y = (["Spending Score (1-100)"]))
# Out:
# <Axes: xlabel='Age', ylabel='[Spending Score (1-100)]'>

# %%
df.plot(kind = 'scatter',x="Age",y = "Spending Score (1-100)",title = "spending salary and Age",color = "g")
       #xlabel = "Age",ylabel = "Spending Score (1-100)")
# Out:
# <Axes: title={'center': 'spending salary and Age'}, xlabel='Age', ylabel='Spending Score (1-100)'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='CustomerID', ylabel='CustomerID'>,
#         <Axes: xlabel='Age', ylabel='CustomerID'>,
#         <Axes: xlabel='Annual Income (k$)', ylabel='CustomerID'>,
#         <Axes: xlabel='Spending Score (1-100)', ylabel='CustomerID'>],
#        [<Axes: xlabel='CustomerID', ylabel='Age'>,
#         <Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='Annual Income (k$)', ylabel='Age'>,
#         <Axes: xlabel='Spending Score (1-100)', ylabel='Age'>],
#        [<Axes: xlabel='CustomerID', ylabel='Annual Income (k$)'>,
#         <Axes: xlabel='Age', ylabel='Annual Income (k$)'>,
#         <Axes: xlabel='Annual Income (k$)', ylabel='Annual Income (k$)'>,
#         <Axes: xlabel='Spending Score (1-100)', ylabel='Annual Income (k$)'>],
#        [<Axes: xlabel='CustomerID', ylabel='Spending Score (1-100)'>,
#         <Axes: xlabel='Age', ylabel='Spending Score (1-100)'>,
#         <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>,
# ...

# %%
from pandas.plotting import bootstrap_plot
bootstrap_plot(df["Annual Income (k$)"])
